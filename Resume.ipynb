# %% [markdown]
# <a href="https://colab.research.google.com/github/tranhoangnguyen03/My_Library/blob/master/Resume.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title    <b>
from IPython.core.display import display, HTML
display(HTML("""
<style>
body { width: 60% !important; }
</style>  
  <img src="http://props.davidustranus.space/QRCode.png" style="float:right;height:100px">
<center>
  <h1> Nguyen H. Tran </h1>
  <h3> 48 Phung Van Cung, Ho Chi Minh city, Vietnam</h3>
  <h3> (+84) 907 491 419 | tranhoangnguyen03@gmail.com</h3>
</center>
  """))

display(HTML("""
<style>
body { width: 90% !important; }
</style>

<body>
  <br>
  <h1> Education </h1>
  <hr width=65%, align=left>
  <p><b>San Francisco State University</b></p>
  <div style="column-count:2">
    <i>Bachelor of Art in Economics</i></p> 
    <p> 2015 </p>
  </div>
  <li><b>GPA:</b> 3.6/4.0; <b>GMAT:</b>  700</li>
  <li><b>Honors:</b> Dean's List (2013,2014)</li>
  <li><b>Areas of Focus:</b> Economics, Statistical Modeling</li>
  <li><b>Areas of Interest:</b> Finance, Business Development</li>
  
  <br>

  <p><b>Online Education and Certifications</b></p>
  <p><i>Google Cloud</i>
    <div style="column-count:2">
      <li><a href="https://www.credential.net/ixzhhxde?key=7f2414293de33c7fd6da21a174d861148b0448b67bfe91b17c9ccfb62f71accc"> Certified Professional Data Engineer</a></li>
      <p> June, 2019 </p>
    </div>
  </p>

  <p><i>Coursera</i>
    <div style="column-count:2">
      <li><a href="https://www.coursera.org/account/accomplishments/specialization/certificate/KFWV9MB2NQMP?utm_medium=certificate&utm_source=link&utm_campaign=copybutton_certificate&utm_term=long">Deep Learning Specialization with DeepLearning.AI</a></li>
      <p> July, 2018 </p>
    </div>
    <div style="column-count:2">
        <li><a href="https://www.coursera.org/account/accomplishments/specialization/certificate/LFMG52Y4Q9ZH?utm_medium=certificate&utm_source=link&utm_campaign=copybutton_certificate&utm_term=long">Machine Learning on TensorFlow with Google Cloud</a></li>
        <p> March, 2019 </p>
    </div>
    <div style="column-count:2">
        <li><a href="https://www.coursera.org/account/accomplishments/specialization/certificate/Z5V99DNCT6U2?utm_medium=certificate&utm_source=link&utm_campaign=copybutton_certificate&utm_term=long">Advanced Machine Learning with Google Cloud</a></li>
        <p> May, 2019 </p>
    </div>
    </p>

    <p><i>Datacamp</i>
      <div style="column-count:2">
          <li><a href="https://www.datacamp.com/statement-of-accomplishment/track/9ae10002c8802fd4cf2ccf8a3d77fb8995d9539d">Data Scientist with Python track</a></li>
          <p> 2018, updated in 2019 </p>
      </div>

      <div style="column-count:2">
          <li><a href="https://www.datacamp.com/profile/tranhoangnguyen03">200+ hours with 59 mini-courses and counting..</a></li>
          <p> On-going </p>
      </div>
  </p>

  <p><i>Emeritus Institute</i>
      <div style="column-count:2">
          <li><a href="https://www.SmartCertificate.com/SmartCertificate/Default.aspx?TMYerY9B5P9ibNw2hDIqm8XuQopYtaxCV8A4VbLZSA7SdiX0o6cN2pVoDge%2bbPj9">Applied Machine Learning with Columbia Engineering Executive Education</a></li>
          <p> March, 2019 </p>
      </div>
  </p>


  <p>
    <img src="https://miro.medium.com/max/500/1*Qq9_pTTcvrfHVfNi2FNphA.png" style="float:left ;height:50px; margin-left:50px;margin-bottom:30px"> 
    <img src="https://s3.amazonaws.com/tlc-company-logo/prod/2x/coursera-org.png" style="float:left;height:50px; margin-left:12px;margin-bottom:30px"> 
    <img src="https://media.glassdoor.com/sqll/1192540/datacamp-squarelogo-1507195211264.png" style="float:left;height:50px;margin-left:12px;margin-bottom:30px"> 
    <img src="https://3k7by215ywuf340yi3alsfso-wpengine.netdna-ssl.com/wp-content/uploads/sites/5/2016/03/Emeritus-Logo.jpg" style="float:left;height:50px;margin-left:20px;margin-bottom:30px">
  </p>
<br>
<br>
</body>
"""))

display(HTML("""
<style>
body { width: 90% !important; }
</style>

<body>
  <p></p>
  <br>
  <br>
  <br>
  <br>
  <h1> Work Experiences and Projects Highlights </h1>
  <hr width=65%, align=left>
  <p><b>Omdena </b></p>
  <div style="column-count:2">
    <i>Project: Machine Learning in Disaster Preparation</i></p> 
    <p> Present </p>
  </div>
  <li><b>Role:</b> Machine Learning Engineer</li>
  <li>Ingest, Extract, Process, and Join GIS data from multiple sources and forms: vectorized shapes & rasterized heatmaps</li>
  <li>Build and Optimize Graph(Network) generation engines for Path-finding pipelines</li>
  <li>Implement succesfully a novel approach to Multi-Objective Pathfinding crucial to the success of project</li>
  <li>Collaborate with Computer Vision Team in building custom Building Detector and Road-Width Detector</li>
  <li>Project Example: <a href="https://colab.research.google.com/drive/10R_ux5Ig6vP5vbEnZeQqg9wcSvE4lOrc#forceEdit=true&sandboxMode=true">Multi-Objective PathFinder</a></li>
  <br>
 
  <p><b>Data Brain Vietnam</b></p>
  <div style="column-count:2">
    <i>Project: Computer Vision in Retails</i></p> 
    <p> 2019 </p>
  </div>
  <li><b>Role:</b> Machine Learning & Pipeline Engineer</li>
  <li>Set up Data Pipelines to ingest from multiple edge sources converging to a Cloud-based sink</li>
  <li>Implemented algorithms to reduce edge-computation workloads, reduce Cloud computation expenses</li>
  <li>Researched, Implemented and Optimized pre-trained Face Detection and Embedding models on low-quality images</li>
  <li>Implemented and Optimized Multi-fold Unsupervised Face Segmentation</li>
  <li>Project Example: <a href="https://colab.research.google.com/drive/1p3jrFxZRC4u3vm-4YtaLU8nEexmyC_Ep#forceEdit=true&sandboxMode=true">Demo_Face_Clustering</a></li>
  <br>
  
  <p><b>Seven Eleven Vietnam</b></p>
  <div style="column-count:2">
    <i>Business Analyst cum Data Analyst</i></p> 
    <p> 2018 </p>
  </div>
  <li>Received trainings on the usage of 3rd party data warehousing SaaS called Domo. </li>
  <li>Performed SQL data querying and ETL operations on a daily basis.</li>
  <li>Assisted multiple departments in data visualization and dashboard construction. </li>
  <li>Performed store-front analysis in conjunction with data mining to improve operation efficiency. </li>
  <li>Performed predictive analysis for operational planning. </li>
  <br>
  
  <p><b>Epinion Vietnam & Decision Lab </b></p>
  <div style="column-count:2">
    <i>Market Research Consultant</i></p> 
    <p> 2015 - 2017 </p>
  </div>
  <li>Designed, executed, and managed multiple market research projects </li>
  <li>Scripted and launched surveys using both in-house hosted application and 3rd party solutions. </li>
  <li>Collected, stored, retrieved, cleaned, and processed small and medium-sized datasets. </li>
  <li>Performed analytics with SPSS, produced visualization with MS Excel, and commentaries with MS PowerPoint. </li>
  <li>Took lead in the development of client-facing online dashboard and survey community management system. </li>
  <br>
  
  <p><b>Etest Test Prep Academy</b></p>
  <div style="column-count:2">
    <i>Academic Coach</i></p> 
    <p> 2016 - Present </p>
  </div>
  <li>Specialty in coaching for IELTS Language Test</li>
  <li>Specialty in coaching for SAT Reading, Writing, and Math </li>
  <li>Proud, Respected, but Bored. On the other hand, Teaching is Lucrative</li>
  <br>
  
  <p><b>Self-initiated Projects</b></p>
  <div style="column-count:2">
    <i>Jack-of-all-Trades</i></p> 
    <p> 2018 - Current </p>
  </div>
  <li><a href="http://regina-spektor.davidustranus.space">Static Web-Radio: Regina Spektor</a></li>
  <li><a href="https://colab.research.google.com/drive/1QoQyURWs9ueTUd_hOXU2JIHRx_lPnHy_?authuser=1#scrollTo=ohqr-d_KIIrP&forceEdit=true&sandboxMode=true">SAT Vocab Practice for SAT students</a></li>
  <li>Real-time scraping of all stock-tickets on Vietnam HOSE exchange (Finished, needs polising)</li>
  <li>Practice Sentences Generator: BERT-based Mutations (Finished, needs polishing)</li>
  <li>Novel analysis: Named Entity Recognition + Relation Extractor (Just-started)</li>  
  <br>
  
  <p>
    <img src="https://media.licdn.com/dms/image/C4D0BAQHewGk35rbUwg/company-logo_200_200/0?e=2159024400&v=beta&t=mEslOjmu0xeEcPhZ8rlvtVGIAWlO-NQqMewRddaEp0A" style="float:left ;height:50px; margin-left:50px;margin-bottom:30px"> 
    <img src="data:image/png;base64,..." style="float:left;height:50px; margin-left:12px;margin-bottom:30px"> 
    <img src="https://is3-ssl.mzstatic.com/image/thumb/Purple123/v4/e9/e5/85/e9e5859f-c649-53bf-08c2-e3307fd41d3c/AppIcon-0-1x_U007emarketing-0-0-GLES2_U002c0-512MB-sRGB-0-0-0-85-220-0-0-0-5.png/246x0w.png" style="float:left;height:50px;margin-left:12px;margin-bottom:30px">
    <img src="https://media.licdn.com/dms/image/C510BAQHxqJ95nqRw6Q/company-logo_200_200/0?e=2159024400&v=beta&t=rwsUfmQ5_BqZ1NirBgqM9i0FDS-XzjOnJag0PbJeK-E" style="float:left;height:50px;margin-left:12px;margin-bottom:30px"> 
    <img src="https://media.licdn.com/dms/image/C4E0BAQEAnhGdkI_NvQ/company-logo_200_200/0?e=2159024400&v=beta&t=MiYqaQYcYxXsRINg034VrnQFQHvMDWhbm1asLyjmeiI" style="float:left;height:50px;margin-left:12px;margin-bottom:30px">
    <img src="http://props.davidustranus.space/My_Logo.png" style="float:left;height:50px;margin-left:12px;margin-bottom:30px">
  </p>
</body>
"""))


import requests, cv2
import matplotlib.pyplot as plt 
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

html = BeautifulSoup(requests.get('http://props.davidustranus.space/scraped_datacamp_profile.txt').content)
skills = pd.DataFrame.from_dict({i.find('h4').getText():int(i.find('p').getText()[:-3])
                        for i in html.find_all(attrs={'class':"topic-block__content"}) 
                        if int(i.find('p').getText()[:-3]) > 5000 }, orient='index', columns=["Datacamp's Estimates"])
skills["Self's Estimates"] = skills.apply(lambda x: x[0]*2 if x.name in ['Data Engineering', 'Data Visualization', 'Importing & Cleaning Data'] else x[0], axis=1)

logos = {'Python': 'https://procodetech.com/wp-content/uploads/2019/04/python.png',
         'sql': 'https://mpng.pngfly.com/20180802/vty/kisspng-clip-art-microsoft-azure-sql-database-microsoft-sq-skills-5b63119fd6c064.4634905815332192318796.jpg',
         'Pandas': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT4vhwI8j1V4oFC-uo4qrd6RIfkJwsbyyGopEGh9BuNAEbR3in4&s',
         'NetworkX': 'https://steemitimages.com/640x0/https://cdn.steemitimages.com/DQmVx2PNYL4otEzTAmTRjWKXoiYzWVFcVV32iXXwEngRbC5/logonetworkx.jpg',
         'Pyspark': 'https://prakhar.me/images/spark.png',
         'Keras': 'https://d1.awsstatic.com/Test%20Images/Kate%20Test%20Images/600x400_keras_Logo.59297d21ef152b2aac8d04e443e1841fbe8c6bab.png',
         'MXNet': 'https://i0.wp.com/syncedreview.com/wp-content/uploads/2018/05/image-30.png?fit=600%2C400&ssl=1',
         'Google Cloud': 'https://www.zenlayer.com/wp-content/uploads/2019/03/Google-Cloud-Logo.png',
         'AWS': 'https://botw-pd.s3.amazonaws.com/styles/logo-thumbnail/s3/102017/logo_0.png?17TK91b1B6OvV2MFrCLfukw1c8oEaNr6&itok=vsanFiUj'}

images = []
montage_image = np.zeros(shape=(200 * 3, 200 * 3, 3), dtype=np.uint8)
cursor_pos = [0, 0]
for i,v in logos.items():
  response = requests.get(v)
  image = np.asarray(bytearray(response.content), dtype="uint8")
  image = cv2.imdecode(image, cv2.IMREAD_COLOR)
  crop_amount = int((image.shape[0]-image.shape[1])/2)
  if crop_amount != 0:
    if crop_amount < 0 : image = image[:,(-crop_amount):crop_amount]
    else: image = image[(crop_amount):(-crop_amount),:]
  image = cv2.resize(image, (200, 200),interpolation = cv2.INTER_AREA)
  montage_image[cursor_pos[1]:cursor_pos[1] + 200, cursor_pos[0]:cursor_pos[0] + 200] = image
  cursor_pos[0] += 200  # increment cursor x position
  if cursor_pos[0] >= 3 * 200:
      cursor_pos[1] += 200  # increment cursor y position
      cursor_pos[0] = 0
display(HTML("""
<style>
body { width: 90% !important; }
</style>
  <body>  
  <p></p>
  <br>
  <br>
  <br>
  <br>
  <br>
  <h1> Skills and Other Details </h1>
  <hr width=65%, align=left>
  <p><b>Technical Highlights: Skills and Technologies </b></p>"""))

fig = plt.figure(figsize = (10,4))
fig.add_subplot(1,2,1)
skills.sort_values("Datacamp's Estimates")["Self's Estimates"].plot(kind='barh', color = 'purple', alpha = 0.7)
skills.sort_values("Datacamp's Estimates")["Datacamp's Estimates"].plot(kind='barh', color = 'orange', alpha = 0.7)
plt.legend(["Self's Estimates","Datacamp's Estimates"],bbox_to_anchor=(0.4, 0.15))
plt.title("Estimation of Nguyen Tran XP distribution", fontsize = 14, x=0, pad=5)
plt.yticks(fontsize =10,)
plt.xticks([])

fig.add_subplot(1,2,2)
plt.imshow(cv2.cvtColor(montage_image, cv2.COLOR_BGR2RGB))
plt.title("Technologies Nguyen Tran is comfortable with", fontsize = 14, pad=10)
plt.yticks([])
plt.xticks([])
plt.show()

display(HTML("""
<style>
body { width: 90% !important; }
</style>
<body>  
<br>
  <p><b>Business Highlights </b></p>
"""))
print("""'\x1b[1;31m'                                          ____________ 
                                            |__________|
  _________________________________        /           /\\
 /                                 \\      /           /  \\
| Critical-thinker, Problem-solver, |    /___________/___/|
| Team-player, Patient, Humourous,  |O   |          |     |
| Resourceful, and Adaptable        | O  |  ==\\ /== |     |
 \\                                 /   O |   O   O  | \ \\ |
  =================================     o|     <    |  \ \\|
                                        /|          |   \ \\
                                       / |  \\_____/ |   / /
                                      / /|          |  / /|
                                     /||\\|          | /||\\/
                                           -------------|   
                                               | |    | | 
                                              <__/    \\__>""")
display(HTML("""
<style>
body { width: 90% !important; }
</style>
<br>
<p><b>Languages</b></p>
  <li>English: Fluent in Writing and Speaking</li>
  <li>Vietnamese: Fluent in Writing and Speaking</li>
<br>
<p><b>Non-work Interests</b></p>
  <li>Writing, Economics, History, Politics, Philosophy, Historical Re-enactment, and Photography. </li>
"""))
# Out:
# <style>
# body { width: 60% !important; }
# </style>
#   <img src="http://props.davidustranus.space/QRCode.png" style="float:right;height:100px">
# <center>
#   <h1> Nguyen H. Tran </h1>
#   <h3> 48 Phung Van Cung, Ho Chi Minh city, Vietnam</h3>
#   <h3> (+84) 907 491 419 | tranhoangnguyen03@gmail.com</h3>
# </center>
# <style>
# body { width: 90% !important; }
# </style>
#
# <body>
#   <br>
#   <h1> Education </h1>
#   <hr width=65%, align=left>
#   <p><b>San Francisco State University</b></p>
#   <div style="column-count:2">
#     <i>Bachelor of Art in Economics</i></p>
#     <p> 2015 </p>
#   </div>
#   <li><b>GPA:</b> 3.6/4.0; <b>GMAT:</b>  700</li>
#   <li><b>Honors:</b> Dean's List (2013,2014)</li>
#   <li><b>Areas of Focus:</b> Economics, Statistical Modeling</li>
#   <li><b>Areas of Interest:</b> Finance, Business Development</li>
#
#   <br>
#
#   <p><b>Online Education and Certifications</b></p>
#   <p><i>Google Cloud</i>
#     <div style="column-count:2">
# ...
